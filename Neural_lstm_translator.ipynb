# %% [markdown]
# # NEURAL MACHINE TRANSLATION
# Implementing an English-French translator

# %%
import helper
import problem_unittests as tests 
source_path = ('./data/small_vocab_en')
target_path = ('./data/small_vocab_fr')
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ### Exploring the Data

# %%
view_sentence_range = (0, 10)

import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ### Implementing text_to_ids function
# to transform source_text and target_text by replacing each letter with its corresponding integers index (from source/target_vocab_to_int)

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    
    source_id_text = [[source_vocab_to_int.get(letter) for letter in line.split()] for line in source_text.split('\n')]

    target_id_text = [[target_vocab_to_int.get(letter) for letter in line.split()] for line in target_text.split('\n')]
    
    for rows in target_id_text:
        rows.insert(len(rows), target_vocab_to_int['<EOS>'])
    
    return source_id_text, target_id_text


tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %%
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# ### Checkpoint

# %%
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Checking if the version of tensorflow is correct and if it has access to GPU

# %%
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# /home/snalessandro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   # This is added back by InteractiveShellApp.init_path()

# %%
def model_inputs():
    inputs = tf.placeholder(tf.int32, shape=[None, None], name = 'input')
    targets = tf.placeholder(tf.int32, shape = [None, None], name='targets')
    keep_prob = tf.placeholder(tf.float32,  shape= None, name= 'keep_prob')
    learning_rate = tf.placeholder(tf.float32, shape = None, name= 'learning_rate')
    return inputs, targets, learning_rate, keep_prob

tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Removing the last word ID from the end of each batch and concatenating the Go ID to the beginning of each batch

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    ending = tf.strided_slice(target_data, [0,0], [batch_size, -1], [1,1])
    go_ = tf.concat([tf.fill([batch_size,1], target_vocab_to_int['<GO>']), ending], 1)
    
    return go_

    
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding Layer
# Encoding using the LSTM Neural Net

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):    
    lstm_1_layer = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop_out = tf.contrib.rnn.DropoutWrapper(lstm_1_layer, output_keep_prob=keep_prob)
    multi_layered_lstm = tf.contrib.rnn.MultiRNNCell([drop_out]*num_layers)
    
    
    #initial_state = multi_layered_lstm.zero_state(rnn_inputs, dtype=tf.float32)
       
    encoded, rnn_state = tf.nn.dynamic_rnn(multi_layered_lstm, rnn_inputs, dtype=tf.float32)


    return rnn_state

tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Training the LSTM Decoder

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, 
                         decoding_scope, output_fn, keep_prob):

    
    decoder = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    
    outputs, final_state_train, context_state_train = tf.contrib.seq2seq.dynamic_rnn_decoder(
        cell= dec_cell, decoder_fn=decoder, inputs= dec_embed_input, sequence_length = sequence_length, scope = decoding_scope)
    
    dropout_outputs = tf.nn.dropout(outputs, keep_prob=keep_prob)
    train_logits = output_fn(dropout_outputs)
    
    return train_logits

tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding Inference

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, 
                         end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):

    decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, dec_embeddings, 
                                                                start_of_sequence_id, end_of_sequence_id, 
                                                                maximum_length, num_decoder_symbols=vocab_size)
    
    out, final_state, context_final_state = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, decoder_fn, 
                                                                                   scope=decoding_scope)
    inference_logits = tf.nn.dropout(out, keep_prob)

    
    return inference_logits
                                                               


tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Building the Decoder Layer

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, 
                   num_layers, target_vocab_to_int, keep_prob):
    

    start_of_sequence_id = target_vocab_to_int['<EOS>']
    end_of_sequence_id = target_vocab_to_int['<GO>']
    
    
    lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dec_cell = tf.contrib.rnn.MultiRNNCell([lstm_cell]*num_layers)
    
    with tf.variable_scope("decoding") as decoding_scope:
        
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope) 
        
        
    with tf.variable_scope("decoding") as decoding_scope:
        train_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, 
                                           output_fn, keep_prob)
        
        
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:    
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, 
                                                end_of_sequence_id, sequence_length, vocab_size, decoding_scope, output_fn, 
                                               keep_prob)
    
    
    return train_logits, inference_logits

tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Building the Neural Network

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length,
                   source_vocab_size, target_vocab_size, enc_embedding_size, dec_embedding_size, 
                  rnn_size, num_layers, target_vocab_to_int):
    
    
    embedding_input = tf.contrib.layers.embed_sequence(input_data, vocab_size=source_vocab_size, 
                                                       embed_dim=enc_embedding_size)
    
    encoder_state = encoding_layer(embedding_input, rnn_size, num_layers, keep_prob)
    
    process_target_data = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    

    
    embedding_output = tf.contrib.layers.embed_sequence(process_target_data, vocab_size=target_vocab_size, 
                                                        embed_dim=dec_embedding_size)
    
                                   
    
    weights = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size], -1., 1.))
    training_logits, inference_logits = decoding_layer(embedding_output, weights, encoder_state, 
                                                       target_vocab_size, sequence_length, rnn_size, 
                                                       num_layers, target_vocab_to_int, keep_prob)
    return (training_logits, inference_logits)


tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ### Hyperparameters

# %%
epochs= 5
learning_rate = 0.001
batch_size = 256
keep_probability = 0.7
encoding_embedding_size = 300
decoding_embedding_size = 300
num_layers = 3
rnn_size = 512

# %% [markdown]
# ### Building the graph

# %%
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])
train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length,
                   len(source_vocab_to_int), len(target_vocab_to_int), encoding_embedding_size, decoding_embedding_size, 
                  rnn_size, num_layers, target_vocab_to_int)
    
    tf.identity(inference_logits, 'logits')
    with tf.name_scope('optimization'):
        #Loss function
        cost = tf.contrib.seq2seq.sequence_loss(train_logits, targets, tf.ones([input_shape[0], sequence_length]))
        
        optimizer = tf.train.AdamOptimizer(lr)
        
        #gradient clipping

        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Training

# %%
import time

def get_accuracy(target, logits):
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(target, [(0,0), (0,max_seq-target.shape[1])], 'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(logits, [(0,0),(0,max_seq - logits.shape[1]), (0,0)], 'constant')
        
    return np.mean(np.equal(target, np.argmax(logits, 2)))    

    

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            _, loss = sess.run([train_op, cost], feed_dict={lr:learning_rate, input_data:source_batch, 
                                                             targets: target_batch, keep_prob:keep_probability, 
                                                            sequence_length:target_batch.shape[1]})
            
            batch_train_logits = sess.run(inference_logits, {input_data:source_batch, keep_prob:1.0})
            batch_valid_logits = sess.run(inference_logits, {input_data: valid_source, keep_prob:1.0})
            
            
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(target_batch), batch_valid_logits)
            
            end_time = time.time()
            
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))
                 
    
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print("Model trained and saved")
# Out:
# Epoch   0 Batch    0/538 - Train Accuracy:  0.138, Validation Accuracy:  0.131, Loss:  5.880
# Epoch   0 Batch    1/538 - Train Accuracy:  0.268, Validation Accuracy:  0.257, Loss:  5.832
# Epoch   0 Batch    2/538 - Train Accuracy:  0.264, Validation Accuracy:  0.264, Loss:  5.332
# Epoch   0 Batch    3/538 - Train Accuracy:  0.265, Validation Accuracy:  0.266, Loss:  4.591
# Epoch   0 Batch    4/538 - Train Accuracy:  0.278, Validation Accuracy:  0.278, Loss:  4.130
# Epoch   0 Batch    5/538 - Train Accuracy:  0.300, Validation Accuracy:  0.298, Loss:  3.810
# Epoch   0 Batch    6/538 - Train Accuracy:  0.339, Validation Accuracy:  0.335, Loss:  3.510
# Epoch   0 Batch    7/538 - Train Accuracy:  0.290, Validation Accuracy:  0.247, Loss:  3.534
# Epoch   0 Batch    8/538 - Train Accuracy:  0.229, Validation Accuracy:  0.199, Loss:  3.375
# Epoch   0 Batch    9/538 - Train Accuracy:  0.266, Validation Accuracy:  0.204, Loss:  3.326
# Epoch   0 Batch   10/538 - Train Accuracy:  0.244, Validation Accuracy:  0.196, Loss:  3.304
# Epoch   0 Batch   11/538 - Train Accuracy:  0.245, Validation Accuracy:  0.207, Loss:  3.159
# Epoch   0 Batch   12/538 - Train Accuracy:  0.273, Validation Accuracy:  0.212, Loss:  3.295
# Epoch   0 Batch   13/538 - Train Accuracy:  0.319, Validation Accuracy:  0.254, Loss:  3.084
# Epoch   0 Batch   14/538 - Train Accuracy:  0.181, Validation Accuracy:  0.189, Loss:  3.115
# Epoch   0 Batch   15/538 - Train Accuracy:  0.213, Validation Accuracy:  0.209, Loss:  2.912
# Epoch   0 Batch   16/538 - Train Accuracy:  0.220, Validation Accuracy:  0.206, Loss:  2.967
# Epoch   0 Batch   17/538 - Train Accuracy:  0.190, Validation Accuracy:  0.170, Loss:  2.950
# Epoch   0 Batch   18/538 - Train Accuracy:  0.212, Validation Accuracy:  0.182, Loss:  2.994
# Epoch   0 Batch   19/538 - Train Accuracy:  0.200, Validation Accuracy:  0.169, Loss:  2.980
# Epoch   0 Batch   20/538 - Train Accuracy:  0.234, Validation Accuracy:  0.211, Loss:  2.762
# Epoch   0 Batch   21/538 - Train Accuracy:  0.161, Validation Accuracy:  0.134, Loss:  2.956
# Epoch   0 Batch   22/538 - Train Accuracy:  0.198, Validation Accuracy:  0.173, Loss:  2.819
# Epoch   0 Batch   23/538 - Train Accuracy:  0.199, Validation Accuracy:  0.175, Loss:  2.747
# Epoch   0 Batch   24/538 - Train Accuracy:  0.241, Validation Accuracy:  0.218, Loss:  2.707
# Epoch   0 Batch   25/538 - Train Accuracy:  0.196, Validation Accuracy:  0.171, Loss:  2.733
# Epoch   0 Batch   26/538 - Train Accuracy:  0.206, Validation Accuracy:  0.172, Loss:  2.696
# Epoch   0 Batch   27/538 - Train Accuracy:  0.202, Validation Accuracy:  0.178, Loss:  2.628
# Epoch   0 Batch   28/538 - Train Accuracy:  0.292, Validation Accuracy:  0.258, Loss:  2.400
# Epoch   0 Batch   29/538 - Train Accuracy:  0.270, Validation Accuracy:  0.235, Loss:  2.517
# Epoch   0 Batch   30/538 - Train Accuracy:  0.222, Validation Accuracy:  0.188, Loss:  2.614
# Epoch   0 Batch   31/538 - Train Accuracy:  0.257, Validation Accuracy:  0.224, Loss:  2.443
# Epoch   0 Batch   32/538 - Train Accuracy:  0.260, Validation Accuracy:  0.230, Loss:  2.484
# Epoch   0 Batch   33/538 - Train Accuracy:  0.264, Validation Accuracy:  0.232, Loss:  2.445
# Epoch   0 Batch   34/538 - Train Accuracy:  0.228, Validation Accuracy:  0.190, Loss:  2.490
# Epoch   0 Batch   35/538 - Train Accuracy:  0.230, Validation Accuracy:  0.191, Loss:  2.478
# Epoch   0 Batch   36/538 - Train Accuracy:  0.253, Validation Accuracy:  0.225, Loss:  2.349
# Epoch   0 Batch   37/538 - Train Accuracy:  0.227, Validation Accuracy:  0.194, Loss:  2.396
# Epoch   0 Batch   38/538 - Train Accuracy:  0.228, Validation Accuracy:  0.191, Loss:  2.432
# Epoch   0 Batch   39/538 - Train Accuracy:  0.219, Validation Accuracy:  0.193, Loss:  2.429
# Epoch   0 Batch   40/538 - Train Accuracy:  0.296, Validation Accuracy:  0.262, Loss:  2.166
# Epoch   0 Batch   41/538 - Train Accuracy:  0.240, Validation Accuracy:  0.199, Loss:  2.354
# Epoch   0 Batch   42/538 - Train Accuracy:  0.228, Validation Accuracy:  0.184, Loss:  2.287
# Epoch   0 Batch   43/538 - Train Accuracy:  0.230, Validation Accuracy:  0.194, Loss:  2.346
# Epoch   0 Batch   44/538 - Train Accuracy:  0.238, Validation Accuracy:  0.199, Loss:  2.342
# Epoch   0 Batch   45/538 - Train Accuracy:  0.261, Validation Accuracy:  0.229, Loss:  2.174
# Epoch   0 Batch   46/538 - Train Accuracy:  0.231, Validation Accuracy:  0.193, Loss:  2.267
# Epoch   0 Batch   47/538 - Train Accuracy:  0.251, Validation Accuracy:  0.216, Loss:  2.164
# Epoch   0 Batch   48/538 - Train Accuracy:  0.253, Validation Accuracy:  0.212, Loss:  2.132
# Epoch   0 Batch   49/538 - Train Accuracy:  0.227, Validation Accuracy:  0.191, Loss:  2.273
# Epoch   0 Batch   50/538 - Train Accuracy:  0.217, Validation Accuracy:  0.182, Loss:  2.173
# Epoch   0 Batch   51/538 - Train Accuracy:  0.202, Validation Accuracy:  0.154, Loss:  2.350
# Epoch   0 Batch   52/538 - Train Accuracy:  0.226, Validation Accuracy:  0.188, Loss:  2.200
# Epoch   0 Batch   53/538 - Train Accuracy:  0.301, Validation Accuracy:  0.257, Loss:  1.999
# Epoch   0 Batch   54/538 - Train Accuracy:  0.242, Validation Accuracy:  0.197, Loss:  2.121
# Epoch   0 Batch   55/538 - Train Accuracy:  0.230, Validation Accuracy:  0.197, Loss:  2.241
# Epoch   0 Batch   56/538 - Train Accuracy:  0.295, Validation Accuracy:  0.245, Loss:  2.232
# Epoch   0 Batch   57/538 - Train Accuracy:  0.240, Validation Accuracy:  0.198, Loss:  2.292
# Epoch   0 Batch   58/538 - Train Accuracy:  0.225, Validation Accuracy:  0.188, Loss:  2.178
# Epoch   0 Batch   59/538 - Train Accuracy:  0.223, Validation Accuracy:  0.189, Loss:  2.237
# Epoch   0 Batch   60/538 - Train Accuracy:  0.248, Validation Accuracy:  0.196, Loss:  2.164
# Epoch   0 Batch   61/538 - Train Accuracy:  0.226, Validation Accuracy:  0.189, Loss:  2.068
# Epoch   0 Batch   62/538 - Train Accuracy:  0.280, Validation Accuracy:  0.241, Loss:  2.091
# Epoch   0 Batch   63/538 - Train Accuracy:  0.282, Validation Accuracy:  0.234, Loss:  1.989
# Epoch   0 Batch   64/538 - Train Accuracy:  0.265, Validation Accuracy:  0.218, Loss:  2.029
# Epoch   0 Batch   65/538 - Train Accuracy:  0.215, Validation Accuracy:  0.183, Loss:  2.107
# Epoch   0 Batch   66/538 - Train Accuracy:  0.271, Validation Accuracy:  0.226, Loss:  1.972
# Epoch   0 Batch   67/538 - Train Accuracy:  0.280, Validation Accuracy:  0.213, Loss:  2.006
# Epoch   0 Batch   68/538 - Train Accuracy:  0.303, Validation Accuracy:  0.251, Loss:  1.908
# Epoch   0 Batch   69/538 - Train Accuracy:  0.232, Validation Accuracy:  0.191, Loss:  2.012
# Epoch   0 Batch   70/538 - Train Accuracy:  0.286, Validation Accuracy:  0.232, Loss:  1.921
# Epoch   0 Batch   71/538 - Train Accuracy:  0.239, Validation Accuracy:  0.187, Loss:  1.969
# Epoch   0 Batch   72/538 - Train Accuracy:  0.302, Validation Accuracy:  0.234, Loss:  1.894
# Epoch   0 Batch   73/538 - Train Accuracy:  0.257, Validation Accuracy:  0.209, Loss:  1.938
# Epoch   0 Batch   74/538 - Train Accuracy:  0.305, Validation Accuracy:  0.251, Loss:  1.884
# Epoch   0 Batch   75/538 - Train Accuracy:  0.285, Validation Accuracy:  0.230, Loss:  1.848
# Epoch   0 Batch   76/538 - Train Accuracy:  0.254, Validation Accuracy:  0.193, Loss:  1.960
# Epoch   0 Batch   77/538 - Train Accuracy:  0.234, Validation Accuracy:  0.184, Loss:  1.878
# Epoch   0 Batch   78/538 - Train Accuracy:  0.278, Validation Accuracy:  0.223, Loss:  1.833
# Epoch   0 Batch   79/538 - Train Accuracy:  0.308, Validation Accuracy:  0.247, Loss:  1.745
# Epoch   0 Batch   80/538 - Train Accuracy:  0.250, Validation Accuracy:  0.198, Loss:  1.891
# Epoch   0 Batch   81/538 - Train Accuracy:  0.245, Validation Accuracy:  0.190, Loss:  1.795
# Epoch   0 Batch   82/538 - Train Accuracy:  0.232, Validation Accuracy:  0.173, Loss:  1.778
# Epoch   0 Batch   83/538 - Train Accuracy:  0.245, Validation Accuracy:  0.182, Loss:  1.775
# Epoch   0 Batch   84/538 - Train Accuracy:  0.294, Validation Accuracy:  0.221, Loss:  1.713
# Epoch   0 Batch   85/538 - Train Accuracy:  0.314, Validation Accuracy:  0.253, Loss:  1.583
# Epoch   0 Batch   86/538 - Train Accuracy:  0.259, Validation Accuracy:  0.196, Loss:  1.758
# Epoch   0 Batch   87/538 - Train Accuracy:  0.239, Validation Accuracy:  0.186, Loss:  1.688
# Epoch   0 Batch   88/538 - Train Accuracy:  0.239, Validation Accuracy:  0.182, Loss:  1.686
# Epoch   0 Batch   89/538 - Train Accuracy:  0.263, Validation Accuracy:  0.194, Loss:  1.665
# Epoch   0 Batch   90/538 - Train Accuracy:  0.296, Validation Accuracy:  0.229, Loss:  1.620
# Epoch   0 Batch   91/538 - Train Accuracy:  0.252, Validation Accuracy:  0.180, Loss:  1.672
# Epoch   0 Batch   92/538 - Train Accuracy:  0.242, Validation Accuracy:  0.175, Loss:  1.616
# Epoch   0 Batch   93/538 - Train Accuracy:  0.248, Validation Accuracy:  0.181, Loss:  1.620
# Epoch   0 Batch   94/538 - Train Accuracy:  0.272, Validation Accuracy:  0.211, Loss:  1.618
# Epoch   0 Batch   95/538 - Train Accuracy:  0.350, Validation Accuracy:  0.291, Loss:  1.459
# Epoch   0 Batch   96/538 - Train Accuracy:  0.318, Validation Accuracy:  0.252, Loss:  1.483
# Epoch   0 Batch   97/538 - Train Accuracy:  0.275, Validation Accuracy:  0.214, Loss:  1.558
# Epoch   0 Batch   98/538 - Train Accuracy:  0.308, Validation Accuracy:  0.250, Loss:  1.447
# Epoch   0 Batch   99/538 - Train Accuracy:  0.256, Validation Accuracy:  0.215, Loss:  1.566
# Epoch   0 Batch  100/538 - Train Accuracy:  0.265, Validation Accuracy:  0.208, Loss:  1.495
# Epoch   0 Batch  101/538 - Train Accuracy:  0.250, Validation Accuracy:  0.194, Loss:  1.536
# Epoch   0 Batch  102/538 - Train Accuracy:  0.246, Validation Accuracy:  0.182, Loss:  1.553
# Epoch   0 Batch  103/538 - Train Accuracy:  0.275, Validation Accuracy:  0.212, Loss:  1.508
# Epoch   0 Batch  104/538 - Train Accuracy:  0.274, Validation Accuracy:  0.221, Loss:  1.473
# Epoch   0 Batch  105/538 - Train Accuracy:  0.303, Validation Accuracy:  0.227, Loss:  1.423
# Epoch   0 Batch  106/538 - Train Accuracy:  0.239, Validation Accuracy:  0.179, Loss:  1.476
# Epoch   0 Batch  107/538 - Train Accuracy:  0.261, Validation Accuracy:  0.185, Loss:  1.508
# Epoch   0 Batch  108/538 - Train Accuracy:  0.248, Validation Accuracy:  0.171, Loss:  1.497
# Epoch   0 Batch  109/538 - Train Accuracy:  0.292, Validation Accuracy:  0.197, Loss:  1.458
# Epoch   0 Batch  110/538 - Train Accuracy:  0.272, Validation Accuracy:  0.191, Loss:  1.494
# Epoch   0 Batch  111/538 - Train Accuracy:  0.308, Validation Accuracy:  0.235, Loss:  1.387
# Epoch   0 Batch  112/538 - Train Accuracy:  0.278, Validation Accuracy:  0.197, Loss:  1.461
# Epoch   0 Batch  113/538 - Train Accuracy:  0.266, Validation Accuracy:  0.191, Loss:  1.459
# Epoch   0 Batch  114/538 - Train Accuracy:  0.284, Validation Accuracy:  0.219, Loss:  1.368
# Epoch   0 Batch  115/538 - Train Accuracy:  0.249, Validation Accuracy:  0.173, Loss:  1.391
# Epoch   0 Batch  116/538 - Train Accuracy:  0.263, Validation Accuracy:  0.216, Loss:  1.405
# Epoch   0 Batch  117/538 - Train Accuracy:  0.278, Validation Accuracy:  0.209, Loss:  1.346
# Epoch   0 Batch  118/538 - Train Accuracy:  0.281, Validation Accuracy:  0.217, Loss:  1.336
# Epoch   0 Batch  119/538 - Train Accuracy:  0.277, Validation Accuracy:  0.216, Loss:  1.322
# Epoch   0 Batch  120/538 - Train Accuracy:  0.254, Validation Accuracy:  0.180, Loss:  1.356
# Epoch   0 Batch  121/538 - Train Accuracy:  0.303, Validation Accuracy:  0.243, Loss:  1.291
# Epoch   0 Batch  122/538 - Train Accuracy:  0.252, Validation Accuracy:  0.202, Loss:  1.291
# Epoch   0 Batch  123/538 - Train Accuracy:  0.258, Validation Accuracy:  0.198, Loss:  1.277
# Epoch   0 Batch  124/538 - Train Accuracy:  0.293, Validation Accuracy:  0.241, Loss:  1.251
# Epoch   0 Batch  125/538 - Train Accuracy:  0.273, Validation Accuracy:  0.206, Loss:  1.316
# Epoch   0 Batch  126/538 - Train Accuracy:  0.279, Validation Accuracy:  0.232, Loss:  1.281
# Epoch   0 Batch  127/538 - Train Accuracy:  0.204, Validation Accuracy:  0.161, Loss:  1.380
# Epoch   0 Batch  128/538 - Train Accuracy:  0.245, Validation Accuracy:  0.201, Loss:  1.288
# Epoch   0 Batch  129/538 - Train Accuracy:  0.241, Validation Accuracy:  0.204, Loss:  1.279
# Epoch   0 Batch  130/538 - Train Accuracy:  0.269, Validation Accuracy:  0.203, Loss:  1.262
# Epoch   0 Batch  131/538 - Train Accuracy:  0.232, Validation Accuracy:  0.171, Loss:  1.333
# Epoch   0 Batch  132/538 - Train Accuracy:  0.265, Validation Accuracy:  0.209, Loss:  1.238
# Epoch   0 Batch  133/538 - Train Accuracy:  0.289, Validation Accuracy:  0.249, Loss:  1.197
# Epoch   0 Batch  134/538 - Train Accuracy:  0.236, Validation Accuracy:  0.179, Loss:  1.334
# Epoch   0 Batch  135/538 - Train Accuracy:  0.249, Validation Accuracy:  0.208, Loss:  1.257
# Epoch   0 Batch  136/538 - Train Accuracy:  0.271, Validation Accuracy:  0.217, Loss:  1.258
# Epoch   0 Batch  137/538 - Train Accuracy:  0.270, Validation Accuracy:  0.221, Loss:  1.255
# Epoch   0 Batch  138/538 - Train Accuracy:  0.271, Validation Accuracy:  0.201, Loss:  1.237
# Epoch   0 Batch  139/538 - Train Accuracy:  0.216, Validation Accuracy:  0.160, Loss:  1.321
# Epoch   0 Batch  140/538 - Train Accuracy:  0.216, Validation Accuracy:  0.155, Loss:  1.303
# Epoch   0 Batch  141/538 - Train Accuracy:  0.227, Validation Accuracy:  0.159, Loss:  1.296
# Epoch   0 Batch  142/538 - Train Accuracy:  0.253, Validation Accuracy:  0.197, Loss:  1.173
# Epoch   0 Batch  143/538 - Train Accuracy:  0.225, Validation Accuracy:  0.160, Loss:  1.247
# Epoch   0 Batch  144/538 - Train Accuracy:  0.217, Validation Accuracy:  0.156, Loss:  1.255
# Epoch   0 Batch  145/538 - Train Accuracy:  0.253, Validation Accuracy:  0.198, Loss:  1.229
# Epoch   0 Batch  146/538 - Train Accuracy:  0.290, Validation Accuracy:  0.234, Loss:  1.158
# Epoch   0 Batch  147/538 - Train Accuracy:  0.277, Validation Accuracy:  0.205, Loss:  1.180
# Epoch   0 Batch  148/538 - Train Accuracy:  0.214, Validation Accuracy:  0.161, Loss:  1.279
# Epoch   0 Batch  149/538 - Train Accuracy:  0.210, Validation Accuracy:  0.161, Loss:  1.193
# Epoch   0 Batch  150/538 - Train Accuracy:  0.222, Validation Accuracy:  0.170, Loss:  1.214
# Epoch   0 Batch  151/538 - Train Accuracy:  0.244, Validation Accuracy:  0.198, Loss:  1.167
# Epoch   0 Batch  152/538 - Train Accuracy:  0.244, Validation Accuracy:  0.201, Loss:  1.159
# Epoch   0 Batch  153/538 - Train Accuracy:  0.270, Validation Accuracy:  0.222, Loss:  1.201
# Epoch   0 Batch  154/538 - Train Accuracy:  0.258, Validation Accuracy:  0.205, Loss:  1.142
# Epoch   0 Batch  155/538 - Train Accuracy:  0.268, Validation Accuracy:  0.225, Loss:  1.158
# Epoch   0 Batch  156/538 - Train Accuracy:  0.244, Validation Accuracy:  0.186, Loss:  1.184
# Epoch   0 Batch  157/538 - Train Accuracy:  0.268, Validation Accuracy:  0.206, Loss:  1.139
# Epoch   0 Batch  158/538 - Train Accuracy:  0.232, Validation Accuracy:  0.164, Loss:  1.189
# Epoch   0 Batch  159/538 - Train Accuracy:  0.201, Validation Accuracy:  0.155, Loss:  1.203
# Epoch   0 Batch  160/538 - Train Accuracy:  0.261, Validation Accuracy:  0.201, Loss:  1.089
# Epoch   0 Batch  161/538 - Train Accuracy:  0.229, Validation Accuracy:  0.175, Loss:  1.149
# Epoch   0 Batch  162/538 - Train Accuracy:  0.262, Validation Accuracy:  0.201, Loss:  1.086
# Epoch   0 Batch  163/538 - Train Accuracy:  0.266, Validation Accuracy:  0.206, Loss:  1.149
# Epoch   0 Batch  164/538 - Train Accuracy:  0.236, Validation Accuracy:  0.162, Loss:  1.169
# Epoch   0 Batch  165/538 - Train Accuracy:  0.256, Validation Accuracy:  0.201, Loss:  1.054
# Epoch   0 Batch  166/538 - Train Accuracy:  0.223, Validation Accuracy:  0.160, Loss:  1.166
# Epoch   0 Batch  167/538 - Train Accuracy:  0.279, Validation Accuracy:  0.204, Loss:  1.104
# Epoch   0 Batch  168/538 - Train Accuracy:  0.226, Validation Accuracy:  0.167, Loss:  1.139
# Epoch   0 Batch  169/538 - Train Accuracy:  0.221, Validation Accuracy:  0.163, Loss:  1.089
# Epoch   0 Batch  170/538 - Train Accuracy:  0.282, Validation Accuracy:  0.209, Loss:  1.111
# Epoch   0 Batch  171/538 - Train Accuracy:  0.235, Validation Accuracy:  0.169, Loss:  1.125
# Epoch   0 Batch  172/538 - Train Accuracy:  0.275, Validation Accuracy:  0.206, Loss:  1.086
# Epoch   0 Batch  173/538 - Train Accuracy:  0.284, Validation Accuracy:  0.214, Loss:  1.061
# Epoch   0 Batch  174/538 - Train Accuracy:  0.231, Validation Accuracy:  0.167, Loss:  1.157
# Epoch   0 Batch  175/538 - Train Accuracy:  0.270, Validation Accuracy:  0.180, Loss:  1.143
# Epoch   0 Batch  176/538 - Train Accuracy:  0.253, Validation Accuracy:  0.186, Loss:  1.117
# Epoch   0 Batch  177/538 - Train Accuracy:  0.281, Validation Accuracy:  0.208, Loss:  1.077
# Epoch   0 Batch  178/538 - Train Accuracy:  0.256, Validation Accuracy:  0.197, Loss:  1.015
# Epoch   0 Batch  179/538 - Train Accuracy:  0.234, Validation Accuracy:  0.164, Loss:  1.069
# Epoch   0 Batch  180/538 - Train Accuracy:  0.269, Validation Accuracy:  0.208, Loss:  1.046
# Epoch   0 Batch  181/538 - Train Accuracy:  0.229, Validation Accuracy:  0.164, Loss:  1.105
# Epoch   0 Batch  182/538 - Train Accuracy:  0.228, Validation Accuracy:  0.168, Loss:  1.067
# Epoch   0 Batch  183/538 - Train Accuracy:  0.260, Validation Accuracy:  0.204, Loss:  0.986
# Epoch   0 Batch  184/538 - Train Accuracy:  0.256, Validation Accuracy:  0.200, Loss:  1.007
# Epoch   0 Batch  185/538 - Train Accuracy:  0.219, Validation Accuracy:  0.158, Loss:  1.022
# Epoch   0 Batch  186/538 - Train Accuracy:  0.267, Validation Accuracy:  0.202, Loss:  1.015
# Epoch   0 Batch  187/538 - Train Accuracy:  0.300, Validation Accuracy:  0.234, Loss:  0.976
# Epoch   0 Batch  188/538 - Train Accuracy:  0.237, Validation Accuracy:  0.160, Loss:  1.027
# Epoch   0 Batch  189/538 - Train Accuracy:  0.230, Validation Accuracy:  0.167, Loss:  1.027
# Epoch   0 Batch  190/538 - Train Accuracy:  0.249, Validation Accuracy:  0.198, Loss:  1.041
# Epoch   0 Batch  191/538 - Train Accuracy:  0.257, Validation Accuracy:  0.203, Loss:  0.973
# Epoch   0 Batch  192/538 - Train Accuracy:  0.264, Validation Accuracy:  0.203, Loss:  0.994
# Epoch   0 Batch  193/538 - Train Accuracy:  0.264, Validation Accuracy:  0.200, Loss:  0.952
# Epoch   0 Batch  194/538 - Train Accuracy:  0.220, Validation Accuracy:  0.165, Loss:  1.016
# Epoch   0 Batch  195/538 - Train Accuracy:  0.244, Validation Accuracy:  0.194, Loss:  0.954
# Epoch   0 Batch  196/538 - Train Accuracy:  0.257, Validation Accuracy:  0.201, Loss:  0.959
# Epoch   0 Batch  197/538 - Train Accuracy:  0.258, Validation Accuracy:  0.196, Loss:  0.956
# Epoch   0 Batch  198/538 - Train Accuracy:  0.242, Validation Accuracy:  0.195, Loss:  0.934
# Epoch   0 Batch  199/538 - Train Accuracy:  0.210, Validation Accuracy:  0.156, Loss:  1.044
# Epoch   0 Batch  200/538 - Train Accuracy:  0.207, Validation Accuracy:  0.157, Loss:  0.975
# Epoch   0 Batch  201/538 - Train Accuracy:  0.242, Validation Accuracy:  0.193, Loss:  0.934
# Epoch   0 Batch  202/538 - Train Accuracy:  0.170, Validation Accuracy:  0.116, Loss:  1.011
# Epoch   0 Batch  203/538 - Train Accuracy:  0.220, Validation Accuracy:  0.164, Loss:  1.001
# Epoch   0 Batch  204/538 - Train Accuracy:  0.213, Validation Accuracy:  0.161, Loss:  0.978
# Epoch   0 Batch  205/538 - Train Accuracy:  0.265, Validation Accuracy:  0.203, Loss:  0.906
# Epoch   0 Batch  206/538 - Train Accuracy:  0.209, Validation Accuracy:  0.157, Loss:  0.981
# Epoch   0 Batch  207/538 - Train Accuracy:  0.249, Validation Accuracy:  0.196, Loss:  0.927
# Epoch   0 Batch  208/538 - Train Accuracy:  0.207, Validation Accuracy:  0.162, Loss:  0.965
# Epoch   0 Batch  209/538 - Train Accuracy:  0.201, Validation Accuracy:  0.162, Loss:  0.962
# Epoch   0 Batch  210/538 - Train Accuracy:  0.241, Validation Accuracy:  0.195, Loss:  0.925
# Epoch   0 Batch  211/538 - Train Accuracy:  0.201, Validation Accuracy:  0.151, Loss:  0.976
# Epoch   0 Batch  212/538 - Train Accuracy:  0.249, Validation Accuracy:  0.205, Loss:  0.928
# Epoch   0 Batch  213/538 - Train Accuracy:  0.247, Validation Accuracy:  0.207, Loss:  0.918
# Epoch   0 Batch  214/538 - Train Accuracy:  0.208, Validation Accuracy:  0.158, Loss:  0.925
# Epoch   0 Batch  215/538 - Train Accuracy:  0.212, Validation Accuracy:  0.159, Loss:  0.945
# Epoch   0 Batch  216/538 - Train Accuracy:  0.193, Validation Accuracy:  0.158, Loss:  0.928
# Epoch   0 Batch  217/538 - Train Accuracy:  0.228, Validation Accuracy:  0.200, Loss:  0.879
# Epoch   0 Batch  218/538 - Train Accuracy:  0.201, Validation Accuracy:  0.154, Loss:  0.913
# Epoch   0 Batch  219/538 - Train Accuracy:  0.203, Validation Accuracy:  0.153, Loss:  0.947
# Epoch   0 Batch  220/538 - Train Accuracy:  0.247, Validation Accuracy:  0.201, Loss:  0.902
# Epoch   0 Batch  221/538 - Train Accuracy:  0.251, Validation Accuracy:  0.201, Loss:  0.873
# Epoch   0 Batch  222/538 - Train Accuracy:  0.247, Validation Accuracy:  0.199, Loss:  0.882
# Epoch   0 Batch  223/538 - Train Accuracy:  0.224, Validation Accuracy:  0.162, Loss:  0.947
# Epoch   0 Batch  224/538 - Train Accuracy:  0.230, Validation Accuracy:  0.176, Loss:  0.936
# Epoch   0 Batch  225/538 - Train Accuracy:  0.262, Validation Accuracy:  0.205, Loss:  0.871
# Epoch   0 Batch  226/538 - Train Accuracy:  0.256, Validation Accuracy:  0.194, Loss:  0.873
# Epoch   0 Batch  227/538 - Train Accuracy:  0.274, Validation Accuracy:  0.225, Loss:  0.839
# Epoch   0 Batch  228/538 - Train Accuracy:  0.246, Validation Accuracy:  0.193, Loss:  0.857
# Epoch   0 Batch  229/538 - Train Accuracy:  0.238, Validation Accuracy:  0.183, Loss:  0.865
# Epoch   0 Batch  230/538 - Train Accuracy:  0.203, Validation Accuracy:  0.152, Loss:  0.891
# Epoch   0 Batch  231/538 - Train Accuracy:  0.211, Validation Accuracy:  0.158, Loss:  0.883
# Epoch   0 Batch  232/538 - Train Accuracy:  0.220, Validation Accuracy:  0.162, Loss:  0.875
# Epoch   0 Batch  233/538 - Train Accuracy:  0.248, Validation Accuracy:  0.199, Loss:  0.877
# Epoch   0 Batch  234/538 - Train Accuracy:  0.199, Validation Accuracy:  0.150, Loss:  0.884
# Epoch   0 Batch  235/538 - Train Accuracy:  0.248, Validation Accuracy:  0.190, Loss:  0.851
# Epoch   0 Batch  236/538 - Train Accuracy:  0.205, Validation Accuracy:  0.143, Loss:  0.906
# Epoch   0 Batch  237/538 - Train Accuracy:  0.204, Validation Accuracy:  0.155, Loss:  0.850
# Epoch   0 Batch  238/538 - Train Accuracy:  0.246, Validation Accuracy:  0.195, Loss:  0.839
# Epoch   0 Batch  239/538 - Train Accuracy:  0.221, Validation Accuracy:  0.157, Loss:  0.884
# Epoch   0 Batch  240/538 - Train Accuracy:  0.205, Validation Accuracy:  0.147, Loss:  0.893
# Epoch   0 Batch  241/538 - Train Accuracy:  0.213, Validation Accuracy:  0.153, Loss:  0.875
# Epoch   0 Batch  242/538 - Train Accuracy:  0.219, Validation Accuracy:  0.163, Loss:  0.840
# Epoch   0 Batch  243/538 - Train Accuracy:  0.169, Validation Accuracy:  0.116, Loss:  0.895
# Epoch   0 Batch  244/538 - Train Accuracy:  0.252, Validation Accuracy:  0.206, Loss:  0.820
# Epoch   0 Batch  245/538 - Train Accuracy:  0.207, Validation Accuracy:  0.154, Loss:  0.869
# Epoch   0 Batch  246/538 - Train Accuracy:  0.254, Validation Accuracy:  0.200, Loss:  0.786
# Epoch   0 Batch  247/538 - Train Accuracy:  0.205, Validation Accuracy:  0.160, Loss:  0.858
# Epoch   0 Batch  248/538 - Train Accuracy:  0.223, Validation Accuracy:  0.162, Loss:  0.841
# Epoch   0 Batch  249/538 - Train Accuracy:  0.247, Validation Accuracy:  0.195, Loss:  0.793
# Epoch   0 Batch  250/538 - Train Accuracy:  0.217, Validation Accuracy:  0.158, Loss:  0.810
# Epoch   0 Batch  251/538 - Train Accuracy:  0.203, Validation Accuracy:  0.151, Loss:  0.839
# Epoch   0 Batch  252/538 - Train Accuracy:  0.259, Validation Accuracy:  0.195, Loss:  0.772
# Epoch   0 Batch  253/538 - Train Accuracy:  0.248, Validation Accuracy:  0.202, Loss:  0.785
# Epoch   0 Batch  254/538 - Train Accuracy:  0.216, Validation Accuracy:  0.154, Loss:  0.840
# Epoch   0 Batch  255/538 - Train Accuracy:  0.213, Validation Accuracy:  0.155, Loss:  0.820
# Epoch   0 Batch  256/538 - Train Accuracy:  0.212, Validation Accuracy:  0.159, Loss:  0.837
# Epoch   0 Batch  257/538 - Train Accuracy:  0.253, Validation Accuracy:  0.191, Loss:  0.793
# Epoch   0 Batch  258/538 - Train Accuracy:  0.262, Validation Accuracy:  0.201, Loss:  0.782
# Epoch   0 Batch  259/538 - Train Accuracy:  0.251, Validation Accuracy:  0.194, Loss:  0.793
# Epoch   0 Batch  260/538 - Train Accuracy:  0.248, Validation Accuracy:  0.205, Loss:  0.803
# Epoch   0 Batch  261/538 - Train Accuracy:  0.222, Validation Accuracy:  0.160, Loss:  0.837
# Epoch   0 Batch  262/538 - Train Accuracy:  0.219, Validation Accuracy:  0.161, Loss:  0.802
# Epoch   0 Batch  263/538 - Train Accuracy:  0.219, Validation Accuracy:  0.155, Loss:  0.802
# Epoch   0 Batch  264/538 - Train Accuracy:  0.219, Validation Accuracy:  0.158, Loss:  0.814
# Epoch   0 Batch  265/538 - Train Accuracy:  0.226, Validation Accuracy:  0.160, Loss:  0.831
# Epoch   0 Batch  266/538 - Train Accuracy:  0.255, Validation Accuracy:  0.196, Loss:  0.791
# Epoch   0 Batch  267/538 - Train Accuracy:  0.230, Validation Accuracy:  0.157, Loss:  0.816
# Epoch   0 Batch  268/538 - Train Accuracy:  0.254, Validation Accuracy:  0.198, Loss:  0.741
# Epoch   0 Batch  269/538 - Train Accuracy:  0.217, Validation Accuracy:  0.155, Loss:  0.849
# Epoch   0 Batch  270/538 - Train Accuracy:  0.236, Validation Accuracy:  0.162, Loss:  0.791
# Epoch   0 Batch  271/538 - Train Accuracy:  0.230, Validation Accuracy:  0.164, Loss:  0.806
# Epoch   0 Batch  272/538 - Train Accuracy:  0.226, Validation Accuracy:  0.163, Loss:  0.850
# Epoch   0 Batch  273/538 - Train Accuracy:  0.222, Validation Accuracy:  0.152, Loss:  0.797
# Epoch   0 Batch  274/538 - Train Accuracy:  0.217, Validation Accuracy:  0.159, Loss:  0.838
# Epoch   0 Batch  275/538 - Train Accuracy:  0.235, Validation Accuracy:  0.168, Loss:  0.833
# Epoch   0 Batch  276/538 - Train Accuracy:  0.216, Validation Accuracy:  0.155, Loss:  0.828
# Epoch   0 Batch  277/538 - Train Accuracy:  0.230, Validation Accuracy:  0.157, Loss:  0.969
# Epoch   0 Batch  278/538 - Train Accuracy:  0.201, Validation Accuracy:  0.164, Loss:  2.498
# Epoch   0 Batch  279/538 - Train Accuracy:  0.158, Validation Accuracy:  0.135, Loss:  2.528
# Epoch   0 Batch  280/538 - Train Accuracy:  0.233, Validation Accuracy:  0.201, Loss:  2.056
# Epoch   0 Batch  281/538 - Train Accuracy:  0.194, Validation Accuracy:  0.173, Loss:  1.471
# Epoch   0 Batch  282/538 - Train Accuracy:  0.243, Validation Accuracy:  0.209, Loss:  1.641
# Epoch   0 Batch  283/538 - Train Accuracy:  0.214, Validation Accuracy:  0.164, Loss:  1.545
# Epoch   0 Batch  284/538 - Train Accuracy:  0.231, Validation Accuracy:  0.176, Loss:  1.240
# Epoch   0 Batch  285/538 - Train Accuracy:  0.258, Validation Accuracy:  0.206, Loss:  1.094
# Epoch   0 Batch  286/538 - Train Accuracy:  0.212, Validation Accuracy:  0.161, Loss:  1.249
# Epoch   0 Batch  287/538 - Train Accuracy:  0.247, Validation Accuracy:  0.202, Loss:  1.167
# Epoch   0 Batch  288/538 - Train Accuracy:  0.216, Validation Accuracy:  0.167, Loss:  1.158
# Epoch   0 Batch  289/538 - Train Accuracy:  0.253, Validation Accuracy:  0.207, Loss:  0.999
# Epoch   0 Batch  290/538 - Train Accuracy:  0.215, Validation Accuracy:  0.166, Loss:  1.050
# Epoch   0 Batch  291/538 - Train Accuracy:  0.255, Validation Accuracy:  0.203, Loss:  1.006
# Epoch   0 Batch  292/538 - Train Accuracy:  0.251, Validation Accuracy:  0.200, Loss:  0.965
# Epoch   0 Batch  293/538 - Train Accuracy:  0.246, Validation Accuracy:  0.195, Loss:  0.973
# Epoch   0 Batch  294/538 - Train Accuracy:  0.176, Validation Accuracy:  0.114, Loss:  1.016
# Epoch   0 Batch  295/538 - Train Accuracy:  0.304, Validation Accuracy:  0.231, Loss:  0.898
# Epoch   0 Batch  296/538 - Train Accuracy:  0.253, Validation Accuracy:  0.195, Loss:  0.909
# Epoch   0 Batch  297/538 - Train Accuracy:  0.219, Validation Accuracy:  0.162, Loss:  0.990
# Epoch   0 Batch  298/538 - Train Accuracy:  0.254, Validation Accuracy:  0.204, Loss:  0.902
# Epoch   0 Batch  299/538 - Train Accuracy:  0.251, Validation Accuracy:  0.203, Loss:  0.913
# Epoch   0 Batch  300/538 - Train Accuracy:  0.257, Validation Accuracy:  0.203, Loss:  0.880
# Epoch   0 Batch  301/538 - Train Accuracy:  0.240, Validation Accuracy:  0.197, Loss:  0.907
# Epoch   0 Batch  302/538 - Train Accuracy:  0.256, Validation Accuracy:  0.195, Loss:  0.857
# Epoch   0 Batch  303/538 - Train Accuracy:  0.297, Validation Accuracy:  0.230, Loss:  0.827
# Epoch   0 Batch  304/538 - Train Accuracy:  0.218, Validation Accuracy:  0.151, Loss:  0.875
# Epoch   0 Batch  305/538 - Train Accuracy:  0.251, Validation Accuracy:  0.198, Loss:  0.829
# Epoch   0 Batch  306/538 - Train Accuracy:  0.243, Validation Accuracy:  0.189, Loss:  0.855
# Epoch   0 Batch  307/538 - Train Accuracy:  0.205, Validation Accuracy:  0.148, Loss:  0.842
# Epoch   0 Batch  308/538 - Train Accuracy:  0.259, Validation Accuracy:  0.196, Loss:  0.814
# Epoch   0 Batch  309/538 - Train Accuracy:  0.215, Validation Accuracy:  0.157, Loss:  0.837
# Epoch   0 Batch  310/538 - Train Accuracy:  0.213, Validation Accuracy:  0.158, Loss:  0.817
# Epoch   0 Batch  311/538 - Train Accuracy:  0.249, Validation Accuracy:  0.196, Loss:  0.811
# Epoch   0 Batch  312/538 - Train Accuracy:  0.273, Validation Accuracy:  0.229, Loss:  0.763
# Epoch   0 Batch  313/538 - Train Accuracy:  0.200, Validation Accuracy:  0.155, Loss:  0.858
# Epoch   0 Batch  314/538 - Train Accuracy:  0.202, Validation Accuracy:  0.155, Loss:  0.820
# Epoch   0 Batch  315/538 - Train Accuracy:  0.238, Validation Accuracy:  0.191, Loss:  0.786
# Epoch   0 Batch  316/538 - Train Accuracy:  0.245, Validation Accuracy:  0.196, Loss:  0.787
# Epoch   0 Batch  317/538 - Train Accuracy:  0.220, Validation Accuracy:  0.157, Loss:  0.813
# Epoch   0 Batch  318/538 - Train Accuracy:  0.239, Validation Accuracy:  0.194, Loss:  0.783
# Epoch   0 Batch  319/538 - Train Accuracy:  0.240, Validation Accuracy:  0.197, Loss:  0.780
# Epoch   0 Batch  320/538 - Train Accuracy:  0.241, Validation Accuracy:  0.194, Loss:  0.774
# Epoch   0 Batch  321/538 - Train Accuracy:  0.244, Validation Accuracy:  0.190, Loss:  0.750
# Epoch   0 Batch  322/538 - Train Accuracy:  0.248, Validation Accuracy:  0.193, Loss:  0.777
# Epoch   0 Batch  323/538 - Train Accuracy:  0.254, Validation Accuracy:  0.195, Loss:  0.750
# Epoch   0 Batch  324/538 - Train Accuracy:  0.206, Validation Accuracy:  0.147, Loss:  0.813
# Epoch   0 Batch  325/538 - Train Accuracy:  0.234, Validation Accuracy:  0.191, Loss:  0.762
# Epoch   0 Batch  326/538 - Train Accuracy:  0.221, Validation Accuracy:  0.154, Loss:  0.773
# Epoch   0 Batch  327/538 - Train Accuracy:  0.217, Validation Accuracy:  0.159, Loss:  0.799
# Epoch   0 Batch  328/538 - Train Accuracy:  0.255, Validation Accuracy:  0.195, Loss:  0.746
# Epoch   0 Batch  329/538 - Train Accuracy:  0.263, Validation Accuracy:  0.195, Loss:  0.739
# Epoch   0 Batch  330/538 - Train Accuracy:  0.244, Validation Accuracy:  0.193, Loss:  0.731
# Epoch   0 Batch  331/538 - Train Accuracy:  0.226, Validation Accuracy:  0.154, Loss:  0.744
# Epoch   0 Batch  332/538 - Train Accuracy:  0.202, Validation Accuracy:  0.153, Loss:  0.775
# Epoch   0 Batch  333/538 - Train Accuracy:  0.254, Validation Accuracy:  0.198, Loss:  0.738
# Epoch   0 Batch  334/538 - Train Accuracy:  0.278, Validation Accuracy:  0.236, Loss:  0.702
# Epoch   0 Batch  335/538 - Train Accuracy:  0.254, Validation Accuracy:  0.198, Loss:  0.733
# Epoch   0 Batch  336/538 - Train Accuracy:  0.244, Validation Accuracy:  0.195, Loss:  0.727
# Epoch   0 Batch  337/538 - Train Accuracy:  0.257, Validation Accuracy:  0.196, Loss:  0.735
# Epoch   0 Batch  338/538 - Train Accuracy:  0.253, Validation Accuracy:  0.198, Loss:  0.755
# Epoch   0 Batch  339/538 - Train Accuracy:  0.253, Validation Accuracy:  0.195, Loss:  0.735
# Epoch   0 Batch  340/538 - Train Accuracy:  0.216, Validation Accuracy:  0.159, Loss:  0.773
# Epoch   0 Batch  341/538 - Train Accuracy:  0.218, Validation Accuracy:  0.154, Loss:  0.733
# Epoch   0 Batch  342/538 - Train Accuracy:  0.255, Validation Accuracy:  0.197, Loss:  0.730
# Epoch   0 Batch  343/538 - Train Accuracy:  0.201, Validation Accuracy:  0.157, Loss:  0.759
# Epoch   0 Batch  344/538 - Train Accuracy:  0.213, Validation Accuracy:  0.151, Loss:  0.749
# Epoch   0 Batch  345/538 - Train Accuracy:  0.247, Validation Accuracy:  0.196, Loss:  0.723
# Epoch   0 Batch  346/538 - Train Accuracy:  0.246, Validation Accuracy:  0.195, Loss:  0.746
# Epoch   0 Batch  347/538 - Train Accuracy:  0.213, Validation Accuracy:  0.149, Loss:  0.737
# Epoch   0 Batch  348/538 - Train Accuracy:  0.252, Validation Accuracy:  0.196, Loss:  0.698
# Epoch   0 Batch  349/538 - Train Accuracy:  0.220, Validation Accuracy:  0.158, Loss:  0.714
# Epoch   0 Batch  350/538 - Train Accuracy:  0.255, Validation Accuracy:  0.196, Loss:  0.737
# Epoch   0 Batch  351/538 - Train Accuracy:  0.219, Validation Accuracy:  0.153, Loss:  0.760
# Epoch   0 Batch  352/538 - Train Accuracy:  0.255, Validation Accuracy:  0.197, Loss:  0.720
# Epoch   0 Batch  353/538 - Train Accuracy:  0.212, Validation Accuracy:  0.156, Loss:  0.758
# Epoch   0 Batch  354/538 - Train Accuracy:  0.220, Validation Accuracy:  0.156, Loss:  0.743
# Epoch   0 Batch  355/538 - Train Accuracy:  0.214, Validation Accuracy:  0.158, Loss:  0.738
# Epoch   0 Batch  356/538 - Train Accuracy:  0.277, Validation Accuracy:  0.233, Loss:  0.677
# Epoch   0 Batch  357/538 - Train Accuracy:  0.214, Validation Accuracy:  0.158, Loss:  0.718
# Epoch   0 Batch  358/538 - Train Accuracy:  0.203, Validation Accuracy:  0.156, Loss:  0.726
# Epoch   0 Batch  359/538 - Train Accuracy:  0.256, Validation Accuracy:  0.198, Loss:  0.708
# Epoch   0 Batch  360/538 - Train Accuracy:  0.205, Validation Accuracy:  0.155, Loss:  0.725
# Epoch   0 Batch  361/538 - Train Accuracy:  0.253, Validation Accuracy:  0.198, Loss:  0.693
# Epoch   0 Batch  362/538 - Train Accuracy:  0.261, Validation Accuracy:  0.196, Loss:  0.684
# Epoch   0 Batch  363/538 - Train Accuracy:  0.235, Validation Accuracy:  0.185, Loss:  0.692
# Epoch   0 Batch  364/538 - Train Accuracy:  0.208, Validation Accuracy:  0.155, Loss:  0.748
# Epoch   0 Batch  365/538 - Train Accuracy:  0.246, Validation Accuracy:  0.194, Loss:  0.701
# Epoch   0 Batch  366/538 - Train Accuracy:  0.224, Validation Accuracy:  0.154, Loss:  0.719
# Epoch   0 Batch  367/538 - Train Accuracy:  0.213, Validation Accuracy:  0.161, Loss:  0.690
# Epoch   0 Batch  368/538 - Train Accuracy:  0.353, Validation Accuracy:  0.296, Loss:  0.627
# Epoch   0 Batch  369/538 - Train Accuracy:  0.219, Validation Accuracy:  0.151, Loss:  0.701
# Epoch   0 Batch  370/538 - Train Accuracy:  0.209, Validation Accuracy:  0.148, Loss:  0.720
# Epoch   0 Batch  371/538 - Train Accuracy:  0.252, Validation Accuracy:  0.192, Loss:  0.686
# Epoch   0 Batch  372/538 - Train Accuracy:  0.212, Validation Accuracy:  0.145, Loss:  0.701
# Epoch   0 Batch  373/538 - Train Accuracy:  0.212, Validation Accuracy:  0.147, Loss:  0.682
# Epoch   0 Batch  374/538 - Train Accuracy:  0.216, Validation Accuracy:  0.153, Loss:  0.721
# Epoch   0 Batch  375/538 - Train Accuracy:  0.251, Validation Accuracy:  0.192, Loss:  0.665
# Epoch   0 Batch  376/538 - Train Accuracy:  0.220, Validation Accuracy:  0.158, Loss:  0.711
# Epoch   0 Batch  377/538 - Train Accuracy:  0.205, Validation Accuracy:  0.153, Loss:  0.693
# Epoch   0 Batch  378/538 - Train Accuracy:  0.256, Validation Accuracy:  0.206, Loss:  0.655
# Epoch   0 Batch  379/538 - Train Accuracy:  0.266, Validation Accuracy:  0.192, Loss:  0.662
# Epoch   0 Batch  380/538 - Train Accuracy:  0.224, Validation Accuracy:  0.155, Loss:  0.679
# Epoch   0 Batch  381/538 - Train Accuracy:  0.254, Validation Accuracy:  0.196, Loss:  0.653
# Epoch   0 Batch  382/538 - Train Accuracy:  0.216, Validation Accuracy:  0.147, Loss:  0.695
# Epoch   0 Batch  383/538 - Train Accuracy:  0.217, Validation Accuracy:  0.155, Loss:  0.689
# Epoch   0 Batch  384/538 - Train Accuracy:  0.253, Validation Accuracy:  0.187, Loss:  0.655
# Epoch   0 Batch  385/538 - Train Accuracy:  0.259, Validation Accuracy:  0.193, Loss:  0.660
# Epoch   0 Batch  386/538 - Train Accuracy:  0.219, Validation Accuracy:  0.160, Loss:  0.691
# Epoch   0 Batch  387/538 - Train Accuracy:  0.216, Validation Accuracy:  0.154, Loss:  0.687
# Epoch   0 Batch  388/538 - Train Accuracy:  0.246, Validation Accuracy:  0.188, Loss:  0.670
# Epoch   0 Batch  389/538 - Train Accuracy:  0.217, Validation Accuracy:  0.152, Loss:  0.716
# Epoch   0 Batch  390/538 - Train Accuracy:  0.254, Validation Accuracy:  0.193, Loss:  0.649
# Epoch   0 Batch  391/538 - Train Accuracy:  0.249, Validation Accuracy:  0.197, Loss:  0.662
# Epoch   0 Batch  392/538 - Train Accuracy:  0.251, Validation Accuracy:  0.198, Loss:  0.648
# Epoch   0 Batch  393/538 - Train Accuracy:  0.250, Validation Accuracy:  0.190, Loss:  0.650
# Epoch   0 Batch  394/538 - Train Accuracy:  0.216, Validation Accuracy:  0.153, Loss:  0.686
# Epoch   0 Batch  395/538 - Train Accuracy:  0.210, Validation Accuracy:  0.148, Loss:  0.701
# Epoch   0 Batch  396/538 - Train Accuracy:  0.221, Validation Accuracy:  0.155, Loss:  0.667
# Epoch   0 Batch  397/538 - Train Accuracy:  0.204, Validation Accuracy:  0.152, Loss:  0.695
# Epoch   0 Batch  398/538 - Train Accuracy:  0.204, Validation Accuracy:  0.155, Loss:  0.675
# Epoch   0 Batch  399/538 - Train Accuracy:  0.207, Validation Accuracy:  0.145, Loss:  0.699
# Epoch   0 Batch  400/538 - Train Accuracy:  0.256, Validation Accuracy:  0.194, Loss:  0.646
# Epoch   0 Batch  401/538 - Train Accuracy:  0.217, Validation Accuracy:  0.154, Loss:  0.677
# Epoch   0 Batch  402/538 - Train Accuracy:  0.220, Validation Accuracy:  0.152, Loss:  0.658
# Epoch   0 Batch  403/538 - Train Accuracy:  0.221, Validation Accuracy:  0.148, Loss:  0.665
# Epoch   0 Batch  404/538 - Train Accuracy:  0.259, Validation Accuracy:  0.198, Loss:  0.638
# Epoch   0 Batch  405/538 - Train Accuracy:  0.260, Validation Accuracy:  0.194, Loss:  0.627
# Epoch   0 Batch  406/538 - Train Accuracy:  0.266, Validation Accuracy:  0.200, Loss:  0.630
# Epoch   0 Batch  407/538 - Train Accuracy:  0.220, Validation Accuracy:  0.157, Loss:  0.656
# Epoch   0 Batch  408/538 - Train Accuracy:  0.201, Validation Accuracy:  0.150, Loss:  0.692
# Epoch   0 Batch  409/538 - Train Accuracy:  0.207, Validation Accuracy:  0.151, Loss:  0.671
# Epoch   0 Batch  410/538 - Train Accuracy:  0.205, Validation Accuracy:  0.159, Loss:  0.665
# Epoch   0 Batch  411/538 - Train Accuracy:  0.242, Validation Accuracy:  0.193, Loss:  0.630
# Epoch   0 Batch  412/538 - Train Accuracy:  0.249, Validation Accuracy:  0.193, Loss:  0.619
# Epoch   0 Batch  413/538 - Train Accuracy:  0.219, Validation Accuracy:  0.155, Loss:  0.649
# Epoch   0 Batch  414/538 - Train Accuracy:  0.212, Validation Accuracy:  0.152, Loss:  0.671
# Epoch   0 Batch  415/538 - Train Accuracy:  0.212, Validation Accuracy:  0.155, Loss:  0.662
# Epoch   0 Batch  416/538 - Train Accuracy:  0.290, Validation Accuracy:  0.235, Loss:  0.624
# Epoch   0 Batch  417/538 - Train Accuracy:  0.214, Validation Accuracy:  0.153, Loss:  0.645
# Epoch   0 Batch  418/538 - Train Accuracy:  0.207, Validation Accuracy:  0.150, Loss:  0.663
# Epoch   0 Batch  419/538 - Train Accuracy:  0.212, Validation Accuracy:  0.154, Loss:  0.626
# Epoch   0 Batch  420/538 - Train Accuracy:  0.212, Validation Accuracy:  0.157, Loss:  0.638
# Epoch   0 Batch  421/538 - Train Accuracy:  0.256, Validation Accuracy:  0.188, Loss:  0.603
# Epoch   0 Batch  422/538 - Train Accuracy:  0.213, Validation Accuracy:  0.157, Loss:  0.642
# Epoch   0 Batch  423/538 - Train Accuracy:  0.207, Validation Accuracy:  0.149, Loss:  0.659
# Epoch   0 Batch  424/538 - Train Accuracy:  0.243, Validation Accuracy:  0.191, Loss:  0.628
# Epoch   0 Batch  425/538 - Train Accuracy:  0.243, Validation Accuracy:  0.193, Loss:  0.634
# Epoch   0 Batch  426/538 - Train Accuracy:  0.207, Validation Accuracy:  0.147, Loss:  0.632
# Epoch   0 Batch  427/538 - Train Accuracy:  0.205, Validation Accuracy:  0.150, Loss:  0.638
# Epoch   0 Batch  428/538 - Train Accuracy:  0.245, Validation Accuracy:  0.190, Loss:  0.610
# Epoch   0 Batch  429/538 - Train Accuracy:  0.254, Validation Accuracy:  0.188, Loss:  0.635
# Epoch   0 Batch  430/538 - Train Accuracy:  0.209, Validation Accuracy:  0.147, Loss:  0.631
# Epoch   0 Batch  431/538 - Train Accuracy:  0.204, Validation Accuracy:  0.148, Loss:  0.635
# Epoch   0 Batch  432/538 - Train Accuracy:  0.273, Validation Accuracy:  0.227, Loss:  0.587
# Epoch   0 Batch  433/538 - Train Accuracy:  0.202, Validation Accuracy:  0.147, Loss:  0.663
# Epoch   0 Batch  434/538 - Train Accuracy:  0.210, Validation Accuracy:  0.155, Loss:  0.643
# Epoch   0 Batch  435/538 - Train Accuracy:  0.207, Validation Accuracy:  0.151, Loss:  0.638
# Epoch   0 Batch  436/538 - Train Accuracy:  0.201, Validation Accuracy:  0.146, Loss:  0.634
# Epoch   0 Batch  437/538 - Train Accuracy:  0.216, Validation Accuracy:  0.157, Loss:  0.637
# Epoch   0 Batch  438/538 - Train Accuracy:  0.214, Validation Accuracy:  0.157, Loss:  0.609
# Epoch   0 Batch  439/538 - Train Accuracy:  0.205, Validation Accuracy:  0.146, Loss:  0.613
# Epoch   0 Batch  440/538 - Train Accuracy:  0.212, Validation Accuracy:  0.158, Loss:  0.654
# Epoch   0 Batch  441/538 - Train Accuracy:  0.211, Validation Accuracy:  0.152, Loss:  0.643
# Epoch   0 Batch  442/538 - Train Accuracy:  0.293, Validation Accuracy:  0.236, Loss:  0.562
# Epoch   0 Batch  443/538 - Train Accuracy:  0.243, Validation Accuracy:  0.193, Loss:  0.605
# Epoch   0 Batch  444/538 - Train Accuracy:  0.248, Validation Accuracy:  0.193, Loss:  0.593
# Epoch   0 Batch  445/538 - Train Accuracy:  0.206, Validation Accuracy:  0.149, Loss:  0.601
# Epoch   0 Batch  446/538 - Train Accuracy:  0.250, Validation Accuracy:  0.192, Loss:  0.589
# Epoch   0 Batch  447/538 - Train Accuracy:  0.216, Validation Accuracy:  0.156, Loss:  0.622
# Epoch   0 Batch  448/538 - Train Accuracy:  0.244, Validation Accuracy:  0.195, Loss:  0.583
# Epoch   0 Batch  449/538 - Train Accuracy:  0.223, Validation Accuracy:  0.151, Loss:  0.646
# Epoch   0 Batch  450/538 - Train Accuracy:  0.241, Validation Accuracy:  0.191, Loss:  0.630
# Epoch   0 Batch  451/538 - Train Accuracy:  0.205, Validation Accuracy:  0.162, Loss:  0.613
# Epoch   0 Batch  452/538 - Train Accuracy:  0.221, Validation Accuracy:  0.157, Loss:  0.597
# Epoch   0 Batch  453/538 - Train Accuracy:  0.211, Validation Accuracy:  0.150, Loss:  0.624
# Epoch   0 Batch  454/538 - Train Accuracy:  0.240, Validation Accuracy:  0.193, Loss:  0.597
# Epoch   0 Batch  455/538 - Train Accuracy:  0.282, Validation Accuracy:  0.227, Loss:  0.560
# Epoch   0 Batch  456/538 - Train Accuracy:  0.333, Validation Accuracy:  0.290, Loss:  0.553
# Epoch   0 Batch  457/538 - Train Accuracy:  0.216, Validation Accuracy:  0.151, Loss:  0.624
# Epoch   0 Batch  458/538 - Train Accuracy:  0.251, Validation Accuracy:  0.194, Loss:  0.588
# Epoch   0 Batch  459/538 - Train Accuracy:  0.219, Validation Accuracy:  0.156, Loss:  0.619
# Epoch   0 Batch  460/538 - Train Accuracy:  0.251, Validation Accuracy:  0.191, Loss:  0.592
# Epoch   0 Batch  461/538 - Train Accuracy:  0.177, Validation Accuracy:  0.111, Loss:  0.649
# Epoch   0 Batch  462/538 - Train Accuracy:  0.254, Validation Accuracy:  0.194, Loss:  0.597
# Epoch   0 Batch  463/538 - Train Accuracy:  0.214, Validation Accuracy:  0.149, Loss:  0.624
# Epoch   0 Batch  464/538 - Train Accuracy:  0.212, Validation Accuracy:  0.156, Loss:  0.618
# Epoch   0 Batch  465/538 - Train Accuracy:  0.210, Validation Accuracy:  0.153, Loss:  0.615
# Epoch   0 Batch  466/538 - Train Accuracy:  0.217, Validation Accuracy:  0.169, Loss:  0.616
# Epoch   0 Batch  467/538 - Train Accuracy:  0.252, Validation Accuracy:  0.197, Loss:  0.591
# Epoch   0 Batch  468/538 - Train Accuracy:  0.226, Validation Accuracy:  0.161, Loss:  0.616
# Epoch   0 Batch  469/538 - Train Accuracy:  0.220, Validation Accuracy:  0.160, Loss:  0.611
# Epoch   0 Batch  470/538 - Train Accuracy:  0.254, Validation Accuracy:  0.195, Loss:  0.590
# Epoch   0 Batch  471/538 - Train Accuracy:  0.255, Validation Accuracy:  0.196, Loss:  0.592
# Epoch   0 Batch  472/538 - Train Accuracy:  0.234, Validation Accuracy:  0.153, Loss:  0.585
# Epoch   0 Batch  473/538 - Train Accuracy:  0.216, Validation Accuracy:  0.155, Loss:  0.614
# Epoch   0 Batch  474/538 - Train Accuracy:  0.254, Validation Accuracy:  0.194, Loss:  0.559
# Epoch   0 Batch  475/538 - Train Accuracy:  0.242, Validation Accuracy:  0.188, Loss:  0.586
# Epoch   0 Batch  476/538 - Train Accuracy:  0.215, Validation Accuracy:  0.152, Loss:  0.603
# Epoch   0 Batch  477/538 - Train Accuracy:  0.206, Validation Accuracy:  0.144, Loss:  0.598
# Epoch   0 Batch  478/538 - Train Accuracy:  0.236, Validation Accuracy:  0.189, Loss:  0.558
# Epoch   0 Batch  479/538 - Train Accuracy:  0.250, Validation Accuracy:  0.185, Loss:  0.565
# Epoch   0 Batch  480/538 - Train Accuracy:  0.255, Validation Accuracy:  0.193, Loss:  0.570
# Epoch   0 Batch  481/538 - Train Accuracy:  0.257, Validation Accuracy:  0.190, Loss:  0.568
# Epoch   0 Batch  482/538 - Train Accuracy:  0.319, Validation Accuracy:  0.264, Loss:  0.523
# Epoch   0 Batch  483/538 - Train Accuracy:  0.202, Validation Accuracy:  0.143, Loss:  0.607
# Epoch   0 Batch  484/538 - Train Accuracy:  0.255, Validation Accuracy:  0.186, Loss:  0.588
# Epoch   0 Batch  485/538 - Train Accuracy:  0.249, Validation Accuracy:  0.189, Loss:  0.575
# Epoch   0 Batch  486/538 - Train Accuracy:  0.250, Validation Accuracy:  0.200, Loss:  0.566
# Epoch   0 Batch  487/538 - Train Accuracy:  0.259, Validation Accuracy:  0.199, Loss:  0.555
# Epoch   0 Batch  488/538 - Train Accuracy:  0.212, Validation Accuracy:  0.156, Loss:  0.589
# Epoch   0 Batch  489/538 - Train Accuracy:  0.218, Validation Accuracy:  0.153, Loss:  0.592
# Epoch   0 Batch  490/538 - Train Accuracy:  0.249, Validation Accuracy:  0.195, Loss:  0.580
# Epoch   0 Batch  491/538 - Train Accuracy:  0.225, Validation Accuracy:  0.156, Loss:  0.599
# Epoch   0 Batch  492/538 - Train Accuracy:  0.234, Validation Accuracy:  0.156, Loss:  0.596
# Epoch   0 Batch  493/538 - Train Accuracy:  0.253, Validation Accuracy:  0.194, Loss:  0.568
# Epoch   0 Batch  494/538 - Train Accuracy:  0.215, Validation Accuracy:  0.148, Loss:  0.596
# Epoch   0 Batch  495/538 - Train Accuracy:  0.215, Validation Accuracy:  0.156, Loss:  0.598
# Epoch   0 Batch  496/538 - Train Accuracy:  0.215, Validation Accuracy:  0.153, Loss:  0.580
# Epoch   0 Batch  497/538 - Train Accuracy:  0.241, Validation Accuracy:  0.187, Loss:  0.562
# Epoch   0 Batch  498/538 - Train Accuracy:  0.219, Validation Accuracy:  0.153, Loss:  0.575
# Epoch   0 Batch  499/538 - Train Accuracy:  0.258, Validation Accuracy:  0.189, Loss:  0.557
# Epoch   0 Batch  500/538 - Train Accuracy:  0.292, Validation Accuracy:  0.222, Loss:  0.535
# Epoch   0 Batch  501/538 - Train Accuracy:  0.210, Validation Accuracy:  0.146, Loss:  0.572
# Epoch   0 Batch  502/538 - Train Accuracy:  0.217, Validation Accuracy:  0.154, Loss:  0.573
# Epoch   0 Batch  503/538 - Train Accuracy:  0.247, Validation Accuracy:  0.186, Loss:  0.562
# Epoch   0 Batch  504/538 - Train Accuracy:  0.222, Validation Accuracy:  0.151, Loss:  0.566
# Epoch   0 Batch  505/538 - Train Accuracy:  0.260, Validation Accuracy:  0.191, Loss:  0.561
# Epoch   0 Batch  506/538 - Train Accuracy:  0.271, Validation Accuracy:  0.198, Loss:  0.563
# Epoch   0 Batch  507/538 - Train Accuracy:  0.264, Validation Accuracy:  0.195, Loss:  0.597
# Epoch   0 Batch  508/538 - Train Accuracy:  0.261, Validation Accuracy:  0.190, Loss:  0.544
# Epoch   0 Batch  509/538 - Train Accuracy:  0.219, Validation Accuracy:  0.153, Loss:  0.583
# Epoch   0 Batch  510/538 - Train Accuracy:  0.263, Validation Accuracy:  0.198, Loss:  0.559
# Epoch   0 Batch  511/538 - Train Accuracy:  0.287, Validation Accuracy:  0.236, Loss:  0.545
# Epoch   0 Batch  512/538 - Train Accuracy:  0.259, Validation Accuracy:  0.194, Loss:  0.547
# Epoch   0 Batch  513/538 - Train Accuracy:  0.254, Validation Accuracy:  0.203, Loss:  0.575
# Epoch   0 Batch  514/538 - Train Accuracy:  0.220, Validation Accuracy:  0.160, Loss:  0.572
# Epoch   0 Batch  515/538 - Train Accuracy:  0.260, Validation Accuracy:  0.188, Loss:  0.564
# ...
# Epoch   4 Batch  366/538 - Train Accuracy:  0.244, Validation Accuracy:  0.137, Loss:  0.034
# Epoch   4 Batch  367/538 - Train Accuracy:  0.242, Validation Accuracy:  0.143, Loss:  0.028
# Epoch   4 Batch  368/538 - Train Accuracy:  0.368, Validation Accuracy:  0.280, Loss:  0.026
# Epoch   4 Batch  369/538 - Train Accuracy:  0.236, Validation Accuracy:  0.139, Loss:  0.028
# Epoch   4 Batch  370/538 - Train Accuracy:  0.229, Validation Accuracy:  0.141, Loss:  0.032
# Epoch   4 Batch  371/538 - Train Accuracy:  0.275, Validation Accuracy:  0.178, Loss:  0.035
# Epoch   4 Batch  372/538 - Train Accuracy:  0.229, Validation Accuracy:  0.135, Loss:  0.031
# Epoch   4 Batch  373/538 - Train Accuracy:  0.234, Validation Accuracy:  0.134, Loss:  0.024
# Epoch   4 Batch  374/538 - Train Accuracy:  0.245, Validation Accuracy:  0.139, Loss:  0.026
# Epoch   4 Batch  375/538 - Train Accuracy:  0.274, Validation Accuracy:  0.180, Loss:  0.027
# Epoch   4 Batch  376/538 - Train Accuracy:  0.236, Validation Accuracy:  0.144, Loss:  0.031
# Epoch   4 Batch  377/538 - Train Accuracy:  0.229, Validation Accuracy:  0.143, Loss:  0.037
# Epoch   4 Batch  378/538 - Train Accuracy:  0.270, Validation Accuracy:  0.185, Loss:  0.028
# Epoch   4 Batch  379/538 - Train Accuracy:  0.273, Validation Accuracy:  0.181, Loss:  0.031
# Epoch   4 Batch  380/538 - Train Accuracy:  0.232, Validation Accuracy:  0.139, Loss:  0.027
# Epoch   4 Batch  381/538 - Train Accuracy:  0.268, Validation Accuracy:  0.182, Loss:  0.029
# Epoch   4 Batch  382/538 - Train Accuracy:  0.233, Validation Accuracy:  0.133, Loss:  0.034
# Epoch   4 Batch  383/538 - Train Accuracy:  0.234, Validation Accuracy:  0.136, Loss:  0.029
# Epoch   4 Batch  384/538 - Train Accuracy:  0.278, Validation Accuracy:  0.182, Loss:  0.030
# Epoch   4 Batch  385/538 - Train Accuracy:  0.285, Validation Accuracy:  0.179, Loss:  0.033
# Epoch   4 Batch  386/538 - Train Accuracy:  0.239, Validation Accuracy:  0.138, Loss:  0.032
# Epoch   4 Batch  387/538 - Train Accuracy:  0.240, Validation Accuracy:  0.140, Loss:  0.034
# Epoch   4 Batch  388/538 - Train Accuracy:  0.268, Validation Accuracy:  0.174, Loss:  0.031
# Epoch   4 Batch  389/538 - Train Accuracy:  0.235, Validation Accuracy:  0.134, Loss:  0.040
# Epoch   4 Batch  390/538 - Train Accuracy:  0.267, Validation Accuracy:  0.181, Loss:  0.027
# Epoch   4 Batch  391/538 - Train Accuracy:  0.264, Validation Accuracy:  0.180, Loss:  0.027
# Epoch   4 Batch  392/538 - Train Accuracy:  0.273, Validation Accuracy:  0.180, Loss:  0.028
# Epoch   4 Batch  393/538 - Train Accuracy:  0.267, Validation Accuracy:  0.178, Loss:  0.030
# Epoch   4 Batch  394/538 - Train Accuracy:  0.230, Validation Accuracy:  0.144, Loss:  0.034
# Epoch   4 Batch  395/538 - Train Accuracy:  0.232, Validation Accuracy:  0.137, Loss:  0.034
# Epoch   4 Batch  396/538 - Train Accuracy:  0.244, Validation Accuracy:  0.143, Loss:  0.026
# Epoch   4 Batch  397/538 - Train Accuracy:  0.237, Validation Accuracy:  0.144, Loss:  0.036
# Epoch   4 Batch  398/538 - Train Accuracy:  0.235, Validation Accuracy:  0.145, Loss:  0.030
# Epoch   4 Batch  399/538 - Train Accuracy:  0.241, Validation Accuracy:  0.139, Loss:  0.038
# Epoch   4 Batch  400/538 - Train Accuracy:  0.282, Validation Accuracy:  0.182, Loss:  0.035
# Epoch   4 Batch  401/538 - Train Accuracy:  0.242, Validation Accuracy:  0.144, Loss:  0.027
# Epoch   4 Batch  402/538 - Train Accuracy:  0.242, Validation Accuracy:  0.145, Loss:  0.026
# Epoch   4 Batch  403/538 - Train Accuracy:  0.227, Validation Accuracy:  0.141, Loss:  0.038
# Epoch   4 Batch  404/538 - Train Accuracy:  0.276, Validation Accuracy:  0.183, Loss:  0.032
# Epoch   4 Batch  405/538 - Train Accuracy:  0.271, Validation Accuracy:  0.186, Loss:  0.031
# Epoch   4 Batch  406/538 - Train Accuracy:  0.273, Validation Accuracy:  0.183, Loss:  0.032
# Epoch   4 Batch  407/538 - Train Accuracy:  0.227, Validation Accuracy:  0.142, Loss:  0.034
# Epoch   4 Batch  408/538 - Train Accuracy:  0.222, Validation Accuracy:  0.137, Loss:  0.038
# Epoch   4 Batch  409/538 - Train Accuracy:  0.218, Validation Accuracy:  0.143, Loss:  0.032
# Epoch   4 Batch  410/538 - Train Accuracy:  0.232, Validation Accuracy:  0.141, Loss:  0.034
# Epoch   4 Batch  411/538 - Train Accuracy:  0.257, Validation Accuracy:  0.180, Loss:  0.040
# Epoch   4 Batch  412/538 - Train Accuracy:  0.271, Validation Accuracy:  0.178, Loss:  0.022
# Epoch   4 Batch  413/538 - Train Accuracy:  0.231, Validation Accuracy:  0.146, Loss:  0.030
# Epoch   4 Batch  414/538 - Train Accuracy:  0.234, Validation Accuracy:  0.139, Loss:  0.041
# Epoch   4 Batch  415/538 - Train Accuracy:  0.238, Validation Accuracy:  0.141, Loss:  0.032
# Epoch   4 Batch  416/538 - Train Accuracy:  0.308, Validation Accuracy:  0.219, Loss:  0.032
# Epoch   4 Batch  417/538 - Train Accuracy:  0.230, Validation Accuracy:  0.136, Loss:  0.032
# Epoch   4 Batch  418/538 - Train Accuracy:  0.219, Validation Accuracy:  0.138, Loss:  0.034
# Epoch   4 Batch  419/538 - Train Accuracy:  0.234, Validation Accuracy:  0.140, Loss:  0.026
# Epoch   4 Batch  420/538 - Train Accuracy:  0.232, Validation Accuracy:  0.140, Loss:  0.031
# Epoch   4 Batch  421/538 - Train Accuracy:  0.274, Validation Accuracy:  0.180, Loss:  0.030
# Epoch   4 Batch  422/538 - Train Accuracy:  0.231, Validation Accuracy:  0.143, Loss:  0.036
# Epoch   4 Batch  423/538 - Train Accuracy:  0.231, Validation Accuracy:  0.140, Loss:  0.032
# Epoch   4 Batch  424/538 - Train Accuracy:  0.269, Validation Accuracy:  0.183, Loss:  0.036
# Epoch   4 Batch  425/538 - Train Accuracy:  0.262, Validation Accuracy:  0.184, Loss:  0.042
# Epoch   4 Batch  426/538 - Train Accuracy:  0.235, Validation Accuracy:  0.139, Loss:  0.032
# Epoch   4 Batch  427/538 - Train Accuracy:  0.232, Validation Accuracy:  0.139, Loss:  0.033
# Epoch   4 Batch  428/538 - Train Accuracy:  0.267, Validation Accuracy:  0.174, Loss:  0.025
# Epoch   4 Batch  429/538 - Train Accuracy:  0.272, Validation Accuracy:  0.181, Loss:  0.033
# Epoch   4 Batch  430/538 - Train Accuracy:  0.233, Validation Accuracy:  0.140, Loss:  0.033
# Epoch   4 Batch  431/538 - Train Accuracy:  0.227, Validation Accuracy:  0.137, Loss:  0.030
# Epoch   4 Batch  432/538 - Train Accuracy:  0.294, Validation Accuracy:  0.219, Loss:  0.037
# Epoch   4 Batch  433/538 - Train Accuracy:  0.231, Validation Accuracy:  0.137, Loss:  0.053
# Epoch   4 Batch  434/538 - Train Accuracy:  0.236, Validation Accuracy:  0.140, Loss:  0.030
# Epoch   4 Batch  435/538 - Train Accuracy:  0.229, Validation Accuracy:  0.132, Loss:  0.031
# Epoch   4 Batch  436/538 - Train Accuracy:  0.235, Validation Accuracy:  0.135, Loss:  0.033
# Epoch   4 Batch  437/538 - Train Accuracy:  0.237, Validation Accuracy:  0.141, Loss:  0.032
# Epoch   4 Batch  438/538 - Train Accuracy:  0.233, Validation Accuracy:  0.138, Loss:  0.028
# Epoch   4 Batch  439/538 - Train Accuracy:  0.228, Validation Accuracy:  0.134, Loss:  0.029
# Epoch   4 Batch  440/538 - Train Accuracy:  0.228, Validation Accuracy:  0.141, Loss:  0.033
# Epoch   4 Batch  441/538 - Train Accuracy:  0.233, Validation Accuracy:  0.135, Loss:  0.038
# Epoch   4 Batch  442/538 - Train Accuracy:  0.295, Validation Accuracy:  0.218, Loss:  0.024
# Epoch   4 Batch  443/538 - Train Accuracy:  0.264, Validation Accuracy:  0.181, Loss:  0.031
# Epoch   4 Batch  444/538 - Train Accuracy:  0.266, Validation Accuracy:  0.177, Loss:  0.028
# Epoch   4 Batch  445/538 - Train Accuracy:  0.222, Validation Accuracy:  0.140, Loss:  0.028
# Epoch   4 Batch  446/538 - Train Accuracy:  0.270, Validation Accuracy:  0.180, Loss:  0.029
# Epoch   4 Batch  447/538 - Train Accuracy:  0.235, Validation Accuracy:  0.144, Loss:  0.031
# Epoch   4 Batch  448/538 - Train Accuracy:  0.276, Validation Accuracy:  0.183, Loss:  0.028
# Epoch   4 Batch  449/538 - Train Accuracy:  0.236, Validation Accuracy:  0.143, Loss:  0.034
# Epoch   4 Batch  450/538 - Train Accuracy:  0.270, Validation Accuracy:  0.176, Loss:  0.044
# Epoch   4 Batch  451/538 - Train Accuracy:  0.228, Validation Accuracy:  0.148, Loss:  0.032
# Epoch   4 Batch  452/538 - Train Accuracy:  0.241, Validation Accuracy:  0.142, Loss:  0.030
# Epoch   4 Batch  453/538 - Train Accuracy:  0.235, Validation Accuracy:  0.140, Loss:  0.039
# Epoch   4 Batch  454/538 - Train Accuracy:  0.257, Validation Accuracy:  0.183, Loss:  0.035
# Epoch   4 Batch  455/538 - Train Accuracy:  0.311, Validation Accuracy:  0.219, Loss:  0.035
# Epoch   4 Batch  456/538 - Train Accuracy:  0.353, Validation Accuracy:  0.280, Loss:  0.057
# Epoch   4 Batch  457/538 - Train Accuracy:  0.246, Validation Accuracy:  0.143, Loss:  0.032
# Epoch   4 Batch  458/538 - Train Accuracy:  0.271, Validation Accuracy:  0.176, Loss:  0.029
# Epoch   4 Batch  459/538 - Train Accuracy:  0.231, Validation Accuracy:  0.145, Loss:  0.026
# Epoch   4 Batch  460/538 - Train Accuracy:  0.276, Validation Accuracy:  0.182, Loss:  0.032
# Epoch   4 Batch  461/538 - Train Accuracy:  0.196, Validation Accuracy:  0.095, Loss:  0.033
# Epoch   4 Batch  462/538 - Train Accuracy:  0.274, Validation Accuracy:  0.184, Loss:  0.033
# Epoch   4 Batch  463/538 - Train Accuracy:  0.222, Validation Accuracy:  0.131, Loss:  0.042
# Epoch   4 Batch  464/538 - Train Accuracy:  0.230, Validation Accuracy:  0.137, Loss:  0.029
# Epoch   4 Batch  465/538 - Train Accuracy:  0.236, Validation Accuracy:  0.140, Loss:  0.030
# Epoch   4 Batch  466/538 - Train Accuracy:  0.243, Validation Accuracy:  0.151, Loss:  0.032
# Epoch   4 Batch  467/538 - Train Accuracy:  0.276, Validation Accuracy:  0.184, Loss:  0.032
# Epoch   4 Batch  468/538 - Train Accuracy:  0.230, Validation Accuracy:  0.143, Loss:  0.037
# Epoch   4 Batch  469/538 - Train Accuracy:  0.242, Validation Accuracy:  0.141, Loss:  0.037
# Epoch   4 Batch  470/538 - Train Accuracy:  0.272, Validation Accuracy:  0.173, Loss:  0.029
# Epoch   4 Batch  471/538 - Train Accuracy:  0.273, Validation Accuracy:  0.185, Loss:  0.027
# Epoch   4 Batch  472/538 - Train Accuracy:  0.239, Validation Accuracy:  0.142, Loss:  0.023
# Epoch   4 Batch  473/538 - Train Accuracy:  0.228, Validation Accuracy:  0.139, Loss:  0.028
# Epoch   4 Batch  474/538 - Train Accuracy:  0.266, Validation Accuracy:  0.181, Loss:  0.027
# Epoch   4 Batch  475/538 - Train Accuracy:  0.265, Validation Accuracy:  0.181, Loss:  0.027
# Epoch   4 Batch  476/538 - Train Accuracy:  0.237, Validation Accuracy:  0.138, Loss:  0.032
# Epoch   4 Batch  477/538 - Train Accuracy:  0.235, Validation Accuracy:  0.133, Loss:  0.034
# Epoch   4 Batch  478/538 - Train Accuracy:  0.257, Validation Accuracy:  0.179, Loss:  0.025
# Epoch   4 Batch  479/538 - Train Accuracy:  0.273, Validation Accuracy:  0.174, Loss:  0.029
# Epoch   4 Batch  480/538 - Train Accuracy:  0.283, Validation Accuracy:  0.177, Loss:  0.027
# Epoch   4 Batch  481/538 - Train Accuracy:  0.275, Validation Accuracy:  0.180, Loss:  0.032
# Epoch   4 Batch  482/538 - Train Accuracy:  0.338, Validation Accuracy:  0.253, Loss:  0.030
# Epoch   4 Batch  483/538 - Train Accuracy:  0.239, Validation Accuracy:  0.132, Loss:  0.037
# Epoch   4 Batch  484/538 - Train Accuracy:  0.267, Validation Accuracy:  0.182, Loss:  0.037
# Epoch   4 Batch  485/538 - Train Accuracy:  0.269, Validation Accuracy:  0.178, Loss:  0.033
# Epoch   4 Batch  486/538 - Train Accuracy:  0.269, Validation Accuracy:  0.183, Loss:  0.027
# Epoch   4 Batch  487/538 - Train Accuracy:  0.274, Validation Accuracy:  0.188, Loss:  0.027
# Epoch   4 Batch  488/538 - Train Accuracy:  0.237, Validation Accuracy:  0.138, Loss:  0.024
# Epoch   4 Batch  489/538 - Train Accuracy:  0.238, Validation Accuracy:  0.143, Loss:  0.031
# Epoch   4 Batch  490/538 - Train Accuracy:  0.267, Validation Accuracy:  0.184, Loss:  0.030
# Epoch   4 Batch  491/538 - Train Accuracy:  0.237, Validation Accuracy:  0.145, Loss:  0.036
# Epoch   4 Batch  492/538 - Train Accuracy:  0.241, Validation Accuracy:  0.138, Loss:  0.030
# Epoch   4 Batch  493/538 - Train Accuracy:  0.271, Validation Accuracy:  0.175, Loss:  0.029
# Epoch   4 Batch  494/538 - Train Accuracy:  0.231, Validation Accuracy:  0.134, Loss:  0.036
# Epoch   4 Batch  495/538 - Train Accuracy:  0.229, Validation Accuracy:  0.137, Loss:  0.031
# Epoch   4 Batch  496/538 - Train Accuracy:  0.236, Validation Accuracy:  0.136, Loss:  0.026
# Epoch   4 Batch  497/538 - Train Accuracy:  0.271, Validation Accuracy:  0.182, Loss:  0.030
# Epoch   4 Batch  498/538 - Train Accuracy:  0.242, Validation Accuracy:  0.144, Loss:  0.030
# Epoch   4 Batch  499/538 - Train Accuracy:  0.267, Validation Accuracy:  0.182, Loss:  0.031
# Epoch   4 Batch  500/538 - Train Accuracy:  0.307, Validation Accuracy:  0.217, Loss:  0.022
# Epoch   4 Batch  501/538 - Train Accuracy:  0.223, Validation Accuracy:  0.135, Loss:  0.031
# Epoch   4 Batch  502/538 - Train Accuracy:  0.239, Validation Accuracy:  0.142, Loss:  0.029
# Epoch   4 Batch  503/538 - Train Accuracy:  0.263, Validation Accuracy:  0.178, Loss:  0.030
# Epoch   4 Batch  504/538 - Train Accuracy:  0.237, Validation Accuracy:  0.138, Loss:  0.024
# Epoch   4 Batch  505/538 - Train Accuracy:  0.283, Validation Accuracy:  0.180, Loss:  0.025
# Epoch   4 Batch  506/538 - Train Accuracy:  0.273, Validation Accuracy:  0.184, Loss:  0.027
# Epoch   4 Batch  507/538 - Train Accuracy:  0.275, Validation Accuracy:  0.185, Loss:  0.037
# Epoch   4 Batch  508/538 - Train Accuracy:  0.267, Validation Accuracy:  0.180, Loss:  0.028
# Epoch   4 Batch  509/538 - Train Accuracy:  0.244, Validation Accuracy:  0.144, Loss:  0.035
# Epoch   4 Batch  510/538 - Train Accuracy:  0.280, Validation Accuracy:  0.182, Loss:  0.031
# Epoch   4 Batch  511/538 - Train Accuracy:  0.306, Validation Accuracy:  0.214, Loss:  0.042
# Epoch   4 Batch  512/538 - Train Accuracy:  0.270, Validation Accuracy:  0.175, Loss:  0.033
# Epoch   4 Batch  513/538 - Train Accuracy:  0.274, Validation Accuracy:  0.182, Loss:  0.033
# Epoch   4 Batch  514/538 - Train Accuracy:  0.236, Validation Accuracy:  0.140, Loss:  0.028
# Epoch   4 Batch  515/538 - Train Accuracy:  0.262, Validation Accuracy:  0.182, Loss:  0.035
# Epoch   4 Batch  516/538 - Train Accuracy:  0.263, Validation Accuracy:  0.180, Loss:  0.033
# Epoch   4 Batch  517/538 - Train Accuracy:  0.274, Validation Accuracy:  0.188, Loss:  0.030
# Epoch   4 Batch  518/538 - Train Accuracy:  0.233, Validation Accuracy:  0.139, Loss:  0.038
# Epoch   4 Batch  519/538 - Train Accuracy:  0.268, Validation Accuracy:  0.185, Loss:  0.031
# Epoch   4 Batch  520/538 - Train Accuracy:  0.244, Validation Accuracy:  0.136, Loss:  0.031
# Epoch   4 Batch  521/538 - Train Accuracy:  0.242, Validation Accuracy:  0.139, Loss:  0.041
# Epoch   4 Batch  522/538 - Train Accuracy:  0.241, Validation Accuracy:  0.136, Loss:  0.032
# Epoch   4 Batch  523/538 - Train Accuracy:  0.234, Validation Accuracy:  0.136, Loss:  0.033
# Epoch   4 Batch  524/538 - Train Accuracy:  0.227, Validation Accuracy:  0.142, Loss:  0.027
# Epoch   4 Batch  525/538 - Train Accuracy:  0.265, Validation Accuracy:  0.179, Loss:  0.034
# Epoch   4 Batch  526/538 - Train Accuracy:  0.271, Validation Accuracy:  0.179, Loss:  0.030
# Epoch   4 Batch  527/538 - Train Accuracy:  0.234, Validation Accuracy:  0.135, Loss:  0.029
# Epoch   4 Batch  528/538 - Train Accuracy:  0.195, Validation Accuracy:  0.098, Loss:  0.035
# Epoch   4 Batch  529/538 - Train Accuracy:  0.229, Validation Accuracy:  0.140, Loss:  0.028
# Epoch   4 Batch  530/538 - Train Accuracy:  0.237, Validation Accuracy:  0.136, Loss:  0.038
# Epoch   4 Batch  531/538 - Train Accuracy:  0.232, Validation Accuracy:  0.146, Loss:  0.038
# Epoch   4 Batch  532/538 - Train Accuracy:  0.234, Validation Accuracy:  0.142, Loss:  0.030
# Epoch   4 Batch  533/538 - Train Accuracy:  0.231, Validation Accuracy:  0.139, Loss:  0.030
# Epoch   4 Batch  534/538 - Train Accuracy:  0.269, Validation Accuracy:  0.181, Loss:  0.026
# Epoch   4 Batch  535/538 - Train Accuracy:  0.267, Validation Accuracy:  0.181, Loss:  0.032
# Epoch   4 Batch  536/538 - Train Accuracy:  0.271, Validation Accuracy:  0.184, Loss:  0.032
# Model trained and saved

# %%
helper.save_params(save_path)

# %% [markdown]
# ### Checkpoint

# %%
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ### Implementing sentence_to_seq
# to process new sentences before feeding them into the model for translation

# %%
def sentence_to_seq(sentence, vocab_to_int):
    sentence_list = []
    sentence = sentence.lower()
    for word in sentence.split(' '):
        if word in vocab_to_int.keys():
            sentence_list.append(vocab_to_int[word])
        else:
            sentence_list.append(vocab_to_int['<UNK>'])    
          
    return sentence_list       


tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ### Translating
# from english to french

# %%
translate_sentence = 'he saw a old yellow truck .'

translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    loader = tf.train.import_meta_graph(load_path +'.meta')
    loader.restore(sess, load_path)
    
    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
    
    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob:1.0})[0]
    
    
print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [180, 41, 177, 172, 186, 130, 120]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [137, 253, 37, 146, 340, 160, 317, 317, 317, 317, 317, 317, 317, 317, 317, 317, 317, 317]
#   French Words: ['elle', 'a', 'vu', 'volant', 'au', 'camion', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']

# %% [markdown]
# ### Imperfect Translation
# You might notice that some sentences translate better than others.
# Since the dataset only has a vocabulary of 227 English words of the thousands that you use,
# you're only going to see good results using these words.
# Additionally, the translations in this data set were made by Google translate,
# so the translations themselves aren't particularly good.
#
# To create a better translation model, it's needed better data.
#
# [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).
# This dataset has more vocabulary and richer in topics discussed.  However, this will take days to train.
